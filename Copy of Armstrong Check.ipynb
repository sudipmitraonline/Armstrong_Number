# %%
# Python program to check if the number is an Armstrong number or not
#@Author : Sudip Mitra
#Contact
# Function : find the sum of the cube of each digit
def armstrong_test(num):
  temp = num
  sum = 0
  while temp > 0:
    digit = temp % 10
    sum += digit ** 3
    temp //= 10
  return sum

while True:
  try:
    a = input("\nEnter the number to check : ")
    if a == "bye":
      print("\nExiting the Program. Thank You from @Author : Sudip Mitra")
      break
    else :
      sum = 0
      a = int(a)
      final_val = armstrong_test(a)
      if final_val == a:
        print(a,"is an Armstrong number. Type 'bye' to exit !")
      else:
        print(a,"is not an Armstrong number. Type 'bye' to exit !")
  except ValueError:
    print("Oops!  That was no valid number.  Try again...")
# Out:
# Enter the number to check : 125
# 125 is not an Armstrong number. Type 'bye' to exit !
#
# Enter the number to check : 153
# 153 is an Armstrong number. Type 'bye' to exit !
#
# Enter the number to check : asd
# Oops!  That was no valid number.  Try again...
#
# Enter the number to check : 370
# 370 is an Armstrong number. Type 'bye' to exit !
#
# Enter the number to check : 1147
# 1147 is not an Armstrong number. Type 'bye' to exit !
#
# Enter the number to check : 457
# 457 is not an Armstrong number. Type 'bye' to exit !
#
# Enter the number to check : bye
#
# Exiting the Program. Thank You from @Author : Sudip Mitra
